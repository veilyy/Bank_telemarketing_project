# %%
import os
import sys
sys.path.append('..')

# %%
import pprint
import os
import pandas as pd
import numpy as np
import subprocess
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib

# %%
df = pd.read_csv('../data/raw/bank-additional-full.csv', sep=';')

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
# Импортируем функции предобработки
from src.preprocessing import *

# %%
result = preprocessing(df)

# %%
result['X_train']
# Out:
#             age  campaign     pdays  previous  emp.var.rate  cons.price.idx  \
# 25611  0.863739  0.522981  0.196584 -0.350127     -0.114858       -0.648967
# 26010 -0.289722 -0.203688  0.196584  1.653813     -0.114858       -0.648967
# 40194  3.651268 -0.567023  0.196584 -0.350127     -1.133161        1.103451
# 297   -0.385843 -0.203688  0.196584 -0.350127      0.648868        0.721890
# 36344  1.824956 -0.203688  0.196584 -0.350127     -1.896888       -1.058152
# ...         ...       ...       ...       ...           ...             ...
# 40205 -1.154817 -0.567023  0.196584 -0.350127     -1.133161        1.103451
# 27316  1.152104 -0.567023  0.196584  1.653813     -0.114858       -0.648967
# 14392  1.344347  0.522981  0.196584 -0.350127      0.839800        0.590675
# 7494  -1.058695 -0.567023  0.196584 -0.350127      0.648868        0.721890
# 10747 -0.481965  0.159647  0.196584 -0.350127      0.839800        1.535081
#
# ...

# %%
result['X_train'].columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'default_unknown', 'contact_telephone',
#        'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar',
#        'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'poutcome_nonexistent', 'poutcome_success', 'housing_unknown',
#        'housing_yes', 'loan_unknown', 'loan_yes', 'day_of_week_mon',
#        'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed'],
#       dtype='object')

# %% [markdown]
# # Сохранение данных

# %%
result['X_train'].to_csv('D:\\Projects\\Bank_UCI_pet_project\\data\\processed\\X_train.csv', index=False)
result['y_train'].to_csv('D:\\Projects\\Bank_UCI_pet_project\\data\\processed\\y_train.csv', index=False)
result['X_test'].to_csv('D:\\Projects\\Bank_UCI_pet_project\\data\\processed\\X_test.csv', index=False)
result['y_test'].to_csv('D:\\Projects\\Bank_UCI_pet_project\\data\\processed\\y_test.csv', index=False)
joblib.dump(result['scaler'], 'D:\\Projects\\Bank_UCI_pet_project\\models/scaler.pkl')
# Out:
# ['D:\\Projects\\Bank_UCI_pet_project\\models/scaler.pkl']
